# %% [markdown]
# # Automatic Blog Article Generator using Python and Machine Learning

# %% [markdown]
# Learn to perform text generation for creating automatic blog articles using the GPT-2 pre-trained model in just 3 lines of code
# with Python.
#
# GPT-2 is a large transformer-based Machine Learning model with 1.5 billion parameters, trained on a dataset of 8 million web
# pages. It is trained with a simple objective: predict the next word, given all of the previous words within some text.
#
# First, let us install the transformers library from Hugging Face for using GPT-2,

# %% [markdown]
# # Installing transformers Library
# pip install transformers

# %% [markdown]
# Next, importing the pipeline function from the transformers library

# %%
# Importing the pipeline function from the transformers Library
from transformers import pipeline

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Creating a TextGenerationPipeline for text generation
generator = pipeline(task='text-generation', model='gpt2')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [18], line 2
#       1 # Creating a TextGenerationPipeline for text generation
# ----> 2 generator = pipeline(task='text-generation', model='gpt2')
#
# File c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\transformers\pipelines\__init__.py:711, in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     707 # Infer the framework from the model
#     708 # Forced if framework already defined, inferred if it's None
#     709 # Will load the correct model if possible
#     710 model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 711 framework, model = infer_framework_load_model(
#     712     model,
# ...

# %% [markdown]
# Note: The gpt2 pre-trained model is large in size so it will take some time to download.
#
# Now, the final step is to give a starting phrase or sentence to the generator pipeline and let the model generate relevant
# text of specified length.

# %%
# Generating
generator("It takes time to write a good blog post.", max_length=300, num_return_sequences=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 2
#       1 # Generating
# ----> 2 generator("It takes time to write a good blog post.", max_length=300, num_return_sequences=3)
#
# NameError: name 'generator' is not defined
